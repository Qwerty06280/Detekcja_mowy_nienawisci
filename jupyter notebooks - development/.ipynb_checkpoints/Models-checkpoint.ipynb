# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# regex - cleaning
import re
# lematyzacja
import spacy
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, ConfusionMatrixDisplay
# Bag of Words
from sklearn.feature_extraction.text import CountVectorizer
# TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer 
# Logistic Regression
from sklearn.linear_model import LogisticRegression
# SVM
from sklearn.svm import SVC
# Naive-Bayes
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# # Read data

# %% [markdown]
# #### Data for training and testing

# %%
file_path_conc = r'C:\Users\Chill\Desktop\INZYNIERKA\dane\found_internet\CONCATENATED_DATA.xlsx'
df_original = pd.read_excel(file_path_conc)

# %%
df_original.head()
# Out:
#                                              Comment  Is_toxic  \
# 0  Dla mnie faworytem do tytułu będzie Cracovia. ...         0
# 1         Brawo ty Daria kibic ma być na dobre i złe         0
# 2  Super, polski premier składa kwiaty na grobach...         0
# 3                        Musi. Innej drogi nie mamy.         0
# 4    Odrzut natychmiastowy, kwaśna mina, mam problem         0
#
#             source
# 0  dataset_poleval
# 1  dataset_poleval
# 2  dataset_poleval
# 3  dataset_poleval
# 4  dataset_poleval

# %% [markdown]
# #### Data to predict

# %%
# Load the CSV file with the correct encoding (UTF-8)
file_path_yt = r'C:\Users\Chill\Desktop\INZYNIERKA\dane\extracted_comments\comms_test.xlsx'
# comments from 4 videos:
# https://www.youtube.com/watch?v=t4O1LLk6qlY
# https://www.youtube.com/watch?v=r3qhl12iHKc
# https://www.youtube.com/watch?v=iLTLbe13hLg
# https://www.youtube.com/watch?v=v7CQkivQNQI

df_predict = pd.read_excel(file_path_yt)

# %%
df_predict.head()
# Out:
#                                             Comments
# 0  JKM jest zwolennikiem otwartej migracji ludzi ...
# 1                              Korwin jest najlepszy
# 2  ten występ się dobrze starzeje jak popatrzymy ...
# 3                   Wracam po protestach we Francji.
# 4  Po 7 latach sie sprawdziło, gosc mysli lata do...

# %% [markdown]
# ## Preprocessing

# %%
df = df_original

# %%
df.isna().sum()
# Out:
# Comment     0
# Is_toxic    0
# source      0
# dtype: int64

# %%
df_original['source'].unique()
# Out:
# array(['dataset_poleval', 'dataset_zwroty', 'dataset_wykop'], dtype=object)

# %%
# Wybieram na razie tylko jeden dataset, najmniej skomplikowany
#df = df[df['source'] == 'dataset_zwroty']
df.head()
# Out:
#                              Comment  Is_toxic          source
# 10041              Nienawidzę gejów.         1  dataset_zwroty
# 10042            Nienawidzę azjatów.         1  dataset_zwroty
# 10043  Nienawidzę niepełnosprawnych.         1  dataset_zwroty
# 10044              Nienawidzę Żydów.         1  dataset_zwroty
# 10045         Nienawidzę imigrantów.         1  dataset_zwroty

# %% [markdown]
# ##### Cleaning

# %%
# re.sub() Replaces one or many matches with a string
# \w characters from a to Z, digits from 0-9, and the underscore _ character
# \s whitespace
# replace with empty string (delete) any character that is not: whitespace, a number, a character a-z or underscore
df['Clean_comment'] = df['Comment'].str.lower().apply(lambda row: re.sub(r'[^\w\s]', '', row))
df.head()
# Out:
# <ipython-input-9-4c9e247495d5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Clean_comment'] = df['Comment'].str.lower().apply(lambda row: re.sub(r'[^\w\s]', '', row))
#                              Comment  Is_toxic          source  \
# 10041              Nienawidzę gejów.         1  dataset_zwroty
# 10042            Nienawidzę azjatów.         1  dataset_zwroty
# 10043  Nienawidzę niepełnosprawnych.         1  dataset_zwroty
# 10044              Nienawidzę Żydów.         1  dataset_zwroty
# 10045         Nienawidzę imigrantów.         1  dataset_zwroty
#
#                       Clean_comment
# 10041              nienawidzę gejów
# 10042            nienawidzę azjatów
# 10043  nienawidzę niepełnosprawnych
# 10044              nienawidzę żydów
# 10045         nienawidzę imigrantów

# %% [markdown]
# ###### Lematyzacja

# %%
nlp = spacy.load('pl_core_news_sm')  # more precise - pl_core_news_lg / less precise & quick pl_core_news_sm

# %%
def lemmatize_text(text):
    doc = nlp(text)
    return ' '.join([token.lemma_ for token in doc])

df['Final_comment'] = df['Clean_comment'].apply(lemmatize_text)
# Out:
# <ipython-input-11-38d1b6c306b4>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Final_comment'] = df['Clean_comment'].apply(lemmatize_text)

# %%
df.head(5)
# Out:
#                              Comment  Is_toxic          source  \
# 10041              Nienawidzę gejów.         1  dataset_zwroty
# 10042            Nienawidzę azjatów.         1  dataset_zwroty
# 10043  Nienawidzę niepełnosprawnych.         1  dataset_zwroty
# 10044              Nienawidzę Żydów.         1  dataset_zwroty
# 10045         Nienawidzę imigrantów.         1  dataset_zwroty
#
#                       Clean_comment                Final_comment
# 10041              nienawidzę gejów              nienawidzić gej
# 10042            nienawidzę azjatów            nienawidzić azjat
# 10043  nienawidzę niepełnosprawnych  nienawidzić niepełnosprawny
# 10044              nienawidzę żydów             nienawidza żydów
# 10045         nienawidzę imigrantów         nienawidzić imigrant

# %% [markdown]
# ##### Stop words - Polish

# %%
with open(r'C:\Users\Chill\Desktop\INZYNIERKA\dane\polish_stopwords.txt', 'r', encoding='utf-8') as file:
    polish_stop_words = [row.strip() for row in file]

# %% [markdown]
# ##### Tokenization & Vectorization

# %% [markdown]
# ### Function - Vectorizer

# %%
def Vectorize(method = 'Bag of Words', stop_words = None):
    if method == 'Bag of Words':
        vectorizer = CountVectorizer(lowercase=True, stop_words=polish_stop_words) # TODO parametry
    elif method =='TF-IDF':
        vectorizer = TfidfVectorizer(lowercase=True, stop_words=polish_stop_words) # TODO parametry
    else:
        raise ValueError("Method not found")
    return vectorizer

# %% [markdown]
# ### Function - make_predictions

# %%
def make_predictions(data, comments_col = 'Final_comment', target_col = 'Is_toxic', vectoraizer_name = 'Bag of Words', 
                     model_name = 'Logistic Regression', stop_words = None, test_size = 0.2, n_splits=5):
    
    vectorizer = Vectorize(method = vectoraizer_name, stop_words = stop_words)
    X = vectorizer.fit_transform(data[comments_col])
    # Split data to training and testing set
    X_train, X_test, y_train, y_test = train_test_split(X, data[target_col], test_size=test_size, random_state=42)
    
    # MODEL
    # Logistic regression
    if model_name == 'Logistic Regression':
        model = LogisticRegression()
    # SVM
    elif model_name == 'SVM':
        model = SVC()
    # Naive-Bayes
    elif model_name == 'Naive-Bayes':
        model = MultinomialNB()
    else:
        raise ValueError('Wrong model_name')
    
    # cross fold validation
    cv_scores = cross_val_score(model, X_train, y_train, cv=n_splits)    
    
    # TRAIN MODEL
    model.fit(X_train, y_train)
    # PREDICT
    predictions = model.predict(X_test)
    
    return y_test, predictions, cv_scores

# %% [markdown]
# ### Function - Visualize results

# %%
def visualize_results(y_test,predictions, cv_scores, model_name: str, vectorizer_name: str):
    cm = confusion_matrix(y_test, predictions)
    cm_display = ConfusionMatrixDisplay(confusion_matrix = cm)
    print(f"MODEL - {model_name.upper()}")
    print(f"VECTORIZER - {vectorizer_name.upper()}")
    print("Dokładność: {}%".format(np.round(accuracy_score(y_test, predictions)*100,2)))
    print(f"Średnia dokładność z walidacji krzyżowej: {cv_scores.mean():.2f} (+/- {cv_scores.std() * 2:.2f})")
    print("Raport klasyfikacji:\n", classification_report(y_test, predictions))
    cm_display.plot(cmap=plt.cm.Greens)
    plt.show()
    print("\n--------------------------------------------------------\n")

# %%
# BoW
logReg_pred = make_predictions(data = df,
                            comments_col = 'Final_comment',
                            target_col  = 'Is_toxic',
                            vectoraizer_name = 'Bag of Words',
                            model_name = 'Logistic Regression',
                            stop_words = polish_stop_words,
                            test_size = 0.2,
                            n_splits=5)

svm_pred = make_predictions(data = df,
                            comments_col = 'Final_comment',
                            target_col  = 'Is_toxic',
                            vectoraizer_name = 'Bag of Words',
                            model_name = 'SVM',
                            stop_words = polish_stop_words,
                            test_size = 0.2,
                            n_splits=5)

nb_pred = make_predictions(data = df,
                            comments_col = 'Final_comment',
                            target_col  = 'Is_toxic',
                            vectoraizer_name = 'Bag of Words',
                            model_name = 'Naive-Bayes',
                            stop_words = polish_stop_words,
                            test_size = 0.2,
                            n_splits=5)

# TF-IDF
logReg_pred_idf = make_predictions(data = df,
                            comments_col = 'Final_comment',
                            target_col  = 'Is_toxic',
                            vectoraizer_name = 'TF-IDF',
                            model_name = 'Logistic Regression',
                            stop_words = polish_stop_words,
                            test_size = 0.2,
                            n_splits=5)

svm_pred_idf = make_predictions(data = df,
                            comments_col = 'Final_comment',
                            target_col  = 'Is_toxic',
                            vectoraizer_name = 'TF-IDF',
                            model_name = 'SVM',
                            stop_words = polish_stop_words,
                            test_size = 0.2,
                            n_splits=5)

nb_pred_idf = make_predictions(data = df,
                            comments_col = 'Final_comment',
                            target_col  = 'Is_toxic',
                            vectoraizer_name = 'TF-IDF',
                            model_name = 'Naive-Bayes',
                            stop_words = polish_stop_words,
                            test_size = 0.2,
                            n_splits=5)

# %%
visualize_results(y_test = logReg_pred[0],
                 predictions = logReg_pred[1],
                 cv_scores = logReg_pred[2],
                 model_name = 'Logisitic Regression',
                 vectorizer_name = 'Bag of Words')

visualize_results(y_test = svm_pred[0],
                 predictions = svm_pred[1],
                 cv_scores = svm_pred[2],
                 model_name = 'SVM',
                 vectorizer_name = 'Bag of Words')

visualize_results(y_test = nb_pred[0],
                 predictions = nb_pred[1],
                 cv_scores = nb_pred[2],
                 model_name = 'Naive-Bayes',
                 vectorizer_name = 'Bag of Words')

visualize_results(y_test = logReg_pred_idf[0],
                 predictions = logReg_pred_idf[1],
                 cv_scores = logReg_pred_idf[2],
                 model_name = 'Logisitic Regression',
                 vectorizer_name = 'TF-IDF')

visualize_results(y_test = svm_pred_idf[0],
                 predictions = svm_pred_idf[1],
                 cv_scores = svm_pred_idf[2],
                 model_name = 'SVM',
                 vectorizer_name = 'TF-IDF')

visualize_results(y_test = nb_pred_idf[0],
                 predictions = nb_pred_idf[1],
                 cv_scores = nb_pred_idf[2],
                 model_name = 'Naive-Bayes',
                 vectorizer_name = 'TF-IDF')
# Out:
# MODEL - LOGISITIC REGRESSION
# VECTORIZER - BAG OF WORDS
# Dokładność: 95.41%
# Średnia dokładność z walidacji krzyżowej: 0.93 (+/- 0.01)
# Raport klasyfikacji:
#                precision    recall  f1-score   support
#
#            0       0.99      0.84      0.91       210
#            1       0.94      1.00      0.97       553
#
#     accuracy                           0.95       763
#    macro avg       0.97      0.92      0.94       763
# weighted avg       0.96      0.95      0.95       763
# --------------------------------------------------------
#
# MODEL - SVM
# VECTORIZER - BAG OF WORDS
# Dokładność: 95.81%
# Średnia dokładność z walidacji krzyżowej: 0.94 (+/- 0.01)
# Raport klasyfikacji:
#                precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92       210
#            1       0.95      1.00      0.97       553
#
#     accuracy                           0.96       763
#    macro avg       0.97      0.92      0.94       763
# weighted avg       0.96      0.96      0.96       763
# --------------------------------------------------------
#
# MODEL - NAIVE-BAYES
# VECTORIZER - BAG OF WORDS
# Dokładność: 95.28%
# Średnia dokładność z walidacji krzyżowej: 0.93 (+/- 0.01)
# Raport klasyfikacji:
#                precision    recall  f1-score   support
#
#            0       0.97      0.85      0.91       210
#            1       0.95      0.99      0.97       553
#
#     accuracy                           0.95       763
#    macro avg       0.96      0.92      0.94       763
# weighted avg       0.95      0.95      0.95       763
# --------------------------------------------------------
#
# MODEL - LOGISITIC REGRESSION
# VECTORIZER - TF-IDF
# Dokładność: 93.18%
# Średnia dokładność z walidacji krzyżowej: 0.90 (+/- 0.02)
# Raport klasyfikacji:
#                precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86       210
#            1       0.91      1.00      0.96       553
#
#     accuracy                           0.93       763
#    macro avg       0.96      0.88      0.91       763
# weighted avg       0.94      0.93      0.93       763
# --------------------------------------------------------
#
# MODEL - SVM
# VECTORIZER - TF-IDF
# Dokładność: 95.94%
# Średnia dokładność z walidacji krzyżowej: 0.95 (+/- 0.01)
# Raport klasyfikacji:
#                precision    recall  f1-score   support
#
#            0       0.99      0.86      0.92       210
#            1       0.95      1.00      0.97       553
#
#     accuracy                           0.96       763
#    macro avg       0.97      0.93      0.95       763
# weighted avg       0.96      0.96      0.96       763
# --------------------------------------------------------
#
# MODEL - NAIVE-BAYES
# VECTORIZER - TF-IDF
# Dokładność: 94.63%
# Średnia dokładność z walidacji krzyżowej: 0.92 (+/- 0.01)
# Raport klasyfikacji:
#                precision    recall  f1-score   support
#
#            0       0.99      0.81      0.89       210
#            1       0.93      1.00      0.96       553
#
#     accuracy                           0.95       763
#    macro avg       0.96      0.91      0.93       763
# weighted avg       0.95      0.95      0.94       763
# --------------------------------------------------------

# %%
df_added_pred = df.loc[list(logReg_pred[0].index)]
df_added_pred['prediction']=logReg_pred[1]
df_added_pred[df_added_pred['Is_toxic']!=df_added_pred['prediction']]
# Out:
#                                                  Comment  Is_toxic  \
# 11254                Jasna cholera, to jest niesamowite.         0
# 12913  Wszystkie pociągi w tym kraju tak bardzo mnie ...         0
# 12957                                 Zrobię ci krzywdę.         1
# 13011  Ci producenci samochodów to nic innego jak kar...         1
# 12870      Ten zestaw ćwiczeń jest po prostu obrzydliwy.         0
# 12152                                     Jestem azjatą.         0
# 11275                    Nic dziwnego, że była wkurzona.         0
# 12357           Tylko azjaci są tak mili i współczujący.         0
# 12386               Życia imigrantów są tak wiele warte.         0
# 11226   Nie mógł się doczekać, kiedy stamtąd wypierdoli.         0
# 11816  Nigdy nie skrzywdziłbym żadnej osoby transpłci...         0
# 11269  Kto tak naprawdę wierzy w te wszystkie bzdury,...         0
# 11245                                   Miałem wyjebane.         0
# 12903             Gdyby tylko ktoś zdusił te inicjatywy.         0
# 11276   Wiem, że nie powinnam dać się tak łatwo wkurzyć.         0
# 12544  Nie możesz poważnie wierzyć, że "azjaci to pom...         0
# 12895  Zamierzamy położyć kres wszelkim zanieczyszcze...         0
# 12156                                    Jestem kobietą.         0
# 12893       Wolałbym umrzeć, niż posiadać taki samochód.         0
# 11309                 To jest naprawdę debilny przykład.         0
# 12359            Tylko Żydzi są tak mili i współczujący.         0
# 12871  Większość ławek w parkach jest absolutnie odra...         0
# 12329                                  Azjaci są piękni.         0
# 11219  Dlaczego, do cholery, nie mogę po prostu pomin...         0
# 11302                           Byłem kompletnym chujem.         0
# 12340    Wszystkie kobiety takie jak one są niesamowite.         0
# 11274            To normalne, że można się o to wkurzyć.         0
# 12900  Byłoby nam lepiej, gdyby ten wirus został zlik...         0
# 12343        Wszyscy azjaci tacy jak oni są niesamowici.         0
# 12902        Tego rodzaju plany powinny być realizowane.         0
# 11272  Moja mama była na mnie naprawdę wkurzona, kied...         0
# 11251           O cholera, zapomniałam zabrać parasolkę.         0
# 12862              Poniedziałki są absolutnie najgorsze.         0
# 11214               Jestem tak cholernie podekscytowany.         0
# 11292  Chciałbym móc powstrzymać się od bycia takim o...         0
#
#                source                                      Clean_comment  \
# 11254  dataset_zwroty                  jasna cholera to jest niesamowite
# 12913  dataset_zwroty  wszystkie pociągi w tym kraju tak bardzo mnie ...
# 12957  dataset_zwroty                                  zrobię ci krzywdę
# 13011  dataset_zwroty  ci producenci samochodów to nic innego jak kar...
# 12870  dataset_zwroty       ten zestaw ćwiczeń jest po prostu obrzydliwy
# 12152  dataset_zwroty                                      jestem azjatą
# 11275  dataset_zwroty                      nic dziwnego że była wkurzona
# 12357  dataset_zwroty            tylko azjaci są tak mili i współczujący
# 12386  dataset_zwroty                życia imigrantów są tak wiele warte
# 11226  dataset_zwroty     nie mógł się doczekać kiedy stamtąd wypierdoli
# 11816  dataset_zwroty  nigdy nie skrzywdziłbym żadnej osoby transpłci...
# 11269  dataset_zwroty  kto tak naprawdę wierzy w te wszystkie bzdury ...
# 11245  dataset_zwroty                                    miałem wyjebane
# 12903  dataset_zwroty              gdyby tylko ktoś zdusił te inicjatywy
# 11276  dataset_zwroty     wiem że nie powinnam dać się tak łatwo wkurzyć
# 12544  dataset_zwroty  nie możesz poważnie wierzyć że azjaci to pomni...
# 12895  dataset_zwroty  zamierzamy położyć kres wszelkim zanieczyszcze...
# 12156  dataset_zwroty                                     jestem kobietą
# 12893  dataset_zwroty         wolałbym umrzeć niż posiadać taki samochód
# 11309  dataset_zwroty                  to jest naprawdę debilny przykład
# 12359  dataset_zwroty             tylko żydzi są tak mili i współczujący
# 12871  dataset_zwroty  większość ławek w parkach jest absolutnie odra...
# 12329  dataset_zwroty                                   azjaci są piękni
# 11219  dataset_zwroty  dlaczego do cholery nie mogę po prostu pominąć...
# 11302  dataset_zwroty                            byłem kompletnym chujem
# 12340  dataset_zwroty     wszystkie kobiety takie jak one są niesamowite
# 11274  dataset_zwroty              to normalne że można się o to wkurzyć
# 12900  dataset_zwroty  byłoby nam lepiej gdyby ten wirus został zlikw...
# 12343  dataset_zwroty         wszyscy azjaci tacy jak oni są niesamowici
# 12902  dataset_zwroty         tego rodzaju plany powinny być realizowane
# 11272  dataset_zwroty  moja mama była na mnie naprawdę wkurzona kiedy...
# 11251  dataset_zwroty             o cholera zapomniałam zabrać parasolkę
# 12862  dataset_zwroty               poniedziałki są absolutnie najgorsze
# 11214  dataset_zwroty                jestem tak cholernie podekscytowany
# 11292  dataset_zwroty  chciałbym móc powstrzymać się od bycia takim o...
#
#                                            Final_comment  prediction
# 11254                    jasny choler to być niesamowity           1
# 12913   wszystek pociąg w ten kraj tak bardzo ja wkurzać           1
# 12957                                  zrobić ty krzywda           0
# 13011    ten producent samochód to nic inny jak karaluch           0
# 12870      ten zestaw ćwiczenie być po prosty obrzydliwy           1
# 12152                                         być azjata           1
# 11275                          nic dziwny że być wkurzić           1
# 12357               tylko azjaci być tak mić i współczuć           1
# 12386                  życie imigrant być tak wiele wart           1
# 11226      nie móc się doczekać kiedy stamtąd wypierdola           1
# 11816  nigdy nie skrzywdzić by być żaden osoba transp...           1
# 11269  kto tak naprawdę wierzyć w ten wszystek bzdura...           1
# 11245                                   mieć być wyjebać           1
# 12903             gdyby tylko ktoś zdusić ten inicjatywa           1
# 11276  wiedzieć że nie powinien być dać się tak łatwo...           1
# 12544  nie móc poważnie wierzyć że azjaci to pomniejy...           1
# 12895    zamierzać położyć kres wszelki zanieczyszczenie           1
# 12156                                        być kobieta           1
# 12893     woleć by być umrzeć niż posiadać taki samochód           1
# 11309                   to być naprawdę debilny przykład           1
# 12359               tylko żydzić być tak mić i współczuć           1
# 12871  większość ławka w parek być absolutnie odrażająca           1
# 12329                                  azjaci być piękny           1
# 11219  dlaczego do cholera nie móc po prosty pominąć ...           1
# 11302                             być być kompletny chuj           1
# 12340       wszystek kobieta taki jak on być niesamowity           1
# 11274              to normalny że można się o to wkurzyć           1
# 12900  być by my dobrze gdyby ten wirus zostać zlikwi...           1
# 12343        wszystek azjaci taki jak on być niesamowici           1
# 12902            ten rodzaj plan powinien być realizować           1
# 11272  mój mama być na ja naprawdę wkurzić kiedy wróc...           1
# 11251            o choler zapomnieć być zabrać parasolka           1
# 12862              poniedziałek być absolutnie najgorsze           1
# 11214                    być tak cholernie podekscytować           1
# 11292  chcieć by być móc powstrzymać się od być taki ...           1
